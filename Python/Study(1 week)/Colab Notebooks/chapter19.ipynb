# %% [markdown]
# ##파일 입출력
#
# ###웹에 있는 데이터는 크롤링을 통해서 데이터베이스에 저장. 1차 클렌징(정제작업)을 거친 후 출력 후 담당자에게 전달
# 웹 -> 크롤링 -> 데이터베이스 -> 1차 클렌징 -> 출력 -> 담당자 -> 2차 클렌징 -> 유용한 데이터셋 -> csv에 입력 -> 인공지능 학습

# %%
pwd
# Out:
# '/content'

# %%
cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %% [markdown]
# r - 읽기
# w - 쓰기 (주의:덮어쓰기)
# a - 추가

# %%
f=open('text.txt','w')
f.write('수강생 여러분')
f.close()

# %%
f=open('text.txt','w')
f.write('개발자 여러분')
f.close()

# %%
f=open('text.txt','w')
f.write('''개발자 여러분
개발자 여러분
개발자 여러분
개발자 여러분
개발자 여러분
개발자 여러분
''')
f.close()

# %%
f=open('text.txt','w')
메세지 = ''

for i in range(10):
    메세지 += "개발자 여러분\n"
f.write(메세지)
f.close()

# %%
f=open('text.txt','r')
s=f.read()
print(s)
f.close()
# Out:
# 개발자 여러분
# 개발자 여러분
# 개발자 여러분
# 개발자 여러분
# 개발자 여러분
# 개발자 여러분
# 개발자 여러분
# 개발자 여러분
# 개발자 여러분
# 개발자 여러분

# %%
f=open('text.txt','r')
line=f.readline()
print(line)
print(type(line))
f.close()
# Out:
# 개발자 여러분
#
# <class 'str'>

# %%
f = open('text.txt','r')
while line:
    line=f.readline()
    print(line)
f.close()

# %%
f=open('text.txt','a')
f.write("힘내자")
f.close()

# %%
with open('text.txt','a') as f:
    f.write('힘내자 !!!')

# %%
list=[10,20,30]

with open('text.txt','a') as f:
    f.write(str(list))

# %%
list = [10,20,30]
with open('text.txt','w') as f:
    f.write('let test =' + str(list))

# %%
list = ["10","20","30"]
with open('text.txt','w') as f:
    f.writelines(list)

# %%
#csv
list = ["10", "20", "30"]

with open('test3.csv', 'w') as f:
    f.write(','.join(list))

# %%
list = ['10', '20', '30', '40']
with open('test1.csv', 'w') as f:
    f.write(','.join(list))
