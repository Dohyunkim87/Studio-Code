# %%
a=550
b=600
c=(a**2+b**2)**(1/2)

print (c)
# Out:
# 813.9410298049853

# %%
a="pig"
b="dad"
print (a+' '+b)
# Out:
# pig dad

# %%
a=110 #시간, 초
b=800 #속도, kb/초
c=a*b/1000
print (c)
# Out:
# 88.0

# %%
family=['mother', 'father', 'me', 'brother']
family[3]
# Out:
# 'brother'

# %%
num = int(input())
print(num * num)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-bd3a6c5c65fb> in <cell line: 1>()
# ----> 1 num = int(input())
#       2 print(num * num)
#
# ValueError: invalid literal for int() with base 10: ''
